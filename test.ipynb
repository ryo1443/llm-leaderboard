# %%
from langchain_anthropic import ChatAnthropic
from langchain_core.prompts import ChatPromptTemplate

chat = ChatAnthropic(temperature=0, model_name="claude-3-opus-20240229", anthropic_api_key= os.environ.get("ANTHROPIC_API_KEY"))

system = (
    "You are a helpful assistant that translates {input_language} to {output_language}."
)
human = "{text}"
prompt = ChatPromptTemplate.from_messages([("system", system), ("human", human)])

chain = prompt | chat
chain.invoke(
    {
        "input_language": "English",
        "output_language": "Japanese",
        "text": "I love Python",
    }
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 13
#      10 prompt = ChatPromptTemplate.from_messages([("system", system), ("human", human)])
#      12 chain = prompt | chat
# ---> 13 chain.invoke(
#      14     {
#      15         "input_language": "English",
#      16         "output_language": "Japanese",
#      17         "text": "I love Python",
#      18     }
#      19 )
#
# File ~/anaconda3/envs/llm-jp/lib/python3.11/site-packages/langchain_core/runnables/base.py:1780, in RunnableSequence.invoke(self, input, config)
#    1778 try:
#    1779     for i, step in enumerate(self.steps):
# -> 1780         input = step.invoke(
#    1781             input,
#    1782             # mark each step as a child run
#    1783             patch_config(
#    1784                 config, callbacks=run_manager.get_child(f"seq:step:{i+1}")
#    1785             ),
#    1786         )
#    1787 # finish the root run
#    1788 except BaseException as e:
#
# File ~/anaconda3/envs/llm-jp/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:165, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     154 def invoke(
#     155     self,
#     156     input: LanguageModelInput,
#    (...)
#     160     **kwargs: Any,
#     161 ) -> BaseMessage:
#     162     config = ensure_config(config)
#     163     return cast(
#     164         ChatGeneration,
# --> 165         self.generate_prompt(
#     166             [self._convert_input(input)],
#     167             stop=stop,
#     168             callbacks=config.get("callbacks"),
#     169             tags=config.get("tags"),
#     170             metadata=config.get("metadata"),
#     171             run_name=config.get("run_name"),
#     172             **kwargs,
#     173         ).generations[0][0],
#     174     ).message
#
# File ~/anaconda3/envs/llm-jp/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:543, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     535 def generate_prompt(
#     536     self,
#     537     prompts: List[PromptValue],
#    (...)
#     540     **kwargs: Any,
#     541 ) -> LLMResult:
#     542     prompt_messages = [p.to_messages() for p in prompts]
# --> 543     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/anaconda3/envs/llm-jp/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:407, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, **kwargs)
#     405         if run_managers:
#     406             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 407         raise e
#     408 flattened_outputs = [
#     409     LLMResult(generations=[res.generations], llm_output=res.llm_output)
#     410     for res in results
#     411 ]
#     412 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File ~/anaconda3/envs/llm-jp/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:397, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, **kwargs)
#     394 for i, m in enumerate(messages):
#     395     try:
#     396         results.append(
# --> 397             self._generate_with_cache(
#     398                 m,
#     399                 stop=stop,
#     400                 run_manager=run_managers[i] if run_managers else None,
#     401                 **kwargs,
#     402             )
#     403         )
#     404     except BaseException as e:
#     405         if run_managers:
#
# File ~/anaconda3/envs/llm-jp/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:576, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     572     raise ValueError(
#     573         "Asked to cache, but no cache found at `langchain.cache`."
#     574     )
#     575 if new_arg_supported:
# --> 576     return self._generate(
#     577         messages, stop=stop, run_manager=run_manager, **kwargs
#     578     )
#     579 else:
#     580     return self._generate(messages, stop=stop, **kwargs)
#
# File ~/anaconda3/envs/llm-jp/lib/python3.11/site-packages/langchain_anthropic/chat_models.py:275, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#     267 def _generate(
#     268     self,
#     269     messages: List[BaseMessage],
#    (...)
#     272     **kwargs: Any,
#     273 ) -> ChatResult:
#     274     params = self._format_params(messages=messages, stop=stop, **kwargs)
# --> 275     data = self._client.messages.create(**params)
#     276     return self._format_output(data, **kwargs)
#
# File ~/anaconda3/envs/llm-jp/lib/python3.11/site-packages/anthropic/_utils/_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273             msg = f"Missing required argument: {quote(missing[0])}"
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/llm-jp/lib/python3.11/site-packages/anthropic/resources/messages.py:638, in Messages.create(self, max_tokens, messages, model, metadata, stop_sequences, stream, system, temperature, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     617 @required_args(["max_tokens", "messages", "model"], ["max_tokens", "messages", "model", "stream"])
#     618 def create(
#     619     self,
#    (...)
#     636     timeout: float | httpx.Timeout | None | NotGiven = 600,
#     637 ) -> Message | Stream[MessageStreamEvent]:
# --> 638     return self._post(
#     639         "/v1/messages",
#     640         body=maybe_transform(
#     641             {
#     642                 "max_tokens": max_tokens,
#     643                 "messages": messages,
#     644                 "model": model,
#     645                 "metadata": metadata,
#     646                 "stop_sequences": stop_sequences,
#     647                 "stream": stream,
#     648                 "system": system,
#     649                 "temperature": temperature,
#     650                 "top_k": top_k,
#     651                 "top_p": top_p,
#     652             },
#     653             message_create_params.MessageCreateParams,
#     654         ),
#     655         options=make_request_options(
#     656             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     657         ),
#     658         cast_to=Message,
#     659         stream=stream or False,
#     660         stream_cls=Stream[MessageStreamEvent],
#     661     )
#
# File ~/anaconda3/envs/llm-jp/lib/python3.11/site-packages/anthropic/_base_client.py:1203, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1189 def post(
#    1190     self,
#    1191     path: str,
#    (...)
#    1198     stream_cls: type[_StreamT] | None = None,
#    1199 ) -> ResponseT | _StreamT:
#    1200     opts = FinalRequestOptions.construct(
#    1201         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1202     )
# -> 1203     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/anaconda3/envs/llm-jp/lib/python3.11/site-packages/anthropic/_base_client.py:892, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     883 def request(
#     884     self,
#     885     cast_to: Type[ResponseT],
#    (...)
#     890     stream_cls: type[_StreamT] | None = None,
#     891 ) -> ResponseT | _StreamT:
# --> 892     return self._request(
#     893         cast_to=cast_to,
#     894         options=options,
#     895         stream=stream,
#     896         stream_cls=stream_cls,
#     897         remaining_retries=remaining_retries,
#     898     )
#
# File ~/anaconda3/envs/llm-jp/lib/python3.11/site-packages/anthropic/_base_client.py:913, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     910 self._prepare_options(options)
#     912 retries = self._remaining_retries(remaining_retries, options)
# --> 913 request = self._build_request(options)
#     914 self._prepare_request(request)
#     916 kwargs: HttpxSendArgs = {}
#
# File ~/anaconda3/envs/llm-jp/lib/python3.11/site-packages/anthropic/_base_client.py:455, in BaseClient._build_request(self, options)
#     452     else:
#     453         raise RuntimeError(f"Unexpected JSON data type, {type(json_data)}, cannot merge with `extra_body`")
# --> 455 headers = self._build_headers(options)
#     456 params = _merge_mappings(self._custom_query, options.params)
#     457 content_type = headers.get("Content-Type")
#
# File ~/anaconda3/envs/llm-jp/lib/python3.11/site-packages/anthropic/_base_client.py:410, in BaseClient._build_headers(self, options)
#     408 custom_headers = options.headers or {}
#     409 headers_dict = _merge_mappings(self.default_headers, custom_headers)
# --> 410 self._validate_headers(headers_dict, custom_headers)
#     412 # headers are case-insensitive while dictionaries are not.
#     413 headers = httpx.Headers(headers_dict)
#
# File ~/anaconda3/envs/llm-jp/lib/python3.11/site-packages/anthropic/_client.py:190, in Anthropic._validate_headers(self, headers, custom_headers)
#     187 if isinstance(custom_headers.get("Authorization"), Omit):
#     188     return
# --> 190 raise TypeError(
#     191     '"Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"'
#     192 )
#
# TypeError: "Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"
